# %%
import numpy as np
import pandas as pd
df = pd.read_csv('data.csv', index_col=0)

# %%
print('Columns:\n{}'.format(df.columns.values))
print('Data Types:\n{}'.format(df.dtypes))
print('Shape:\n{}'.format(df.shape))
# Out:
# Columns:
# ['name' 'desc' 'goal' 'keywords' 'disable_communication' 'country'
#  'currency' 'deadline' 'state_changed_at' 'created_at' 'launched_at'
#  'backers_count' 'final_status']
# Data Types:
# name                      object
# desc                      object
# goal                     float64
# keywords                  object
# disable_communication       bool
# country                   object
# currency                  object
# deadline                   int64
# state_changed_at           int64
# created_at                 int64
# launched_at                int64
# backers_count              int64
# final_status               int64
# dtype: object
# Shape:
# (108129, 13)

# %%
# Drop 'created_at' and 'currency' columns for dimension reduction and also importance
# currency column is proxy for country anyways
df = df.drop(['created_at','currency'], axis=1)
df.head()
# Out:
#                                                              name  \
# project_id
# kkst1451568084                                drawing for dollars
# kkst1474482071  Sponsor Dereck Blackburn (Lostwars) Artist in ...
# kkst183622197                                       Mr. Squiggles
# kkst597742710                      Help me write my second novel.
# kkst1913131122             Support casting my sculpture in bronze
#
#                                                              desc    goal  \
# project_id
# kkst1451568084  I like drawing pictures. and then i color them...    20.0
# kkst1474482071  I, Dereck Blackburn will be taking upon an inc...   300.0
# kkst183622197   So I saw darkpony's successfully funded drawin...    30.0
# kkst597742710   Do your part to help out starving artists and ...   500.0
# kkst1913131122  I'm nearing completion on a sculpture, current...  2000.0
#
#                                                          keywords  \
# project_id
# kkst1451568084                                drawing-for-dollars
# kkst1474482071  sponsor-dereck-blackburn-lostwars-artist-in-re...
# kkst183622197                                        mr-squiggles
# kkst597742710                       help-me-write-my-second-novel
# kkst1913131122             support-casting-my-sculpture-in-bronze
#
#                 disable_communication country    deadline  state_changed_at  \
# project_id
# kkst1451568084                  False      US  1241333999        1241334017
# kkst1474482071                  False      US  1242429000        1242432018
# kkst183622197                   False      US  1243027560        1243027818
# kkst597742710                   False      US  1243555740        1243556121
# kkst1913131122                  False      US  1243769880        1243770317
#
#                 launched_at  backers_count  final_status
# project_id
# kkst1451568084   1240602723              3             1
# kkst1474482071   1240975592              2             0
# kkst183622197    1242164398              0             0
# kkst597742710    1240966730             18             1
# kkst1913131122   1241180541              1             0

# %%
unix_time_columns = ['deadline','state_changed_at','launched_at']
for col in unix_time_columns:
    col_name = col+'_dt'
    df[col_name] = pd.to_datetime(df[col],unit='s')

# %%
# feature engineering 1 (duration)
# leave in unix time because only care about the difference
df['expected_duration'] = df['deadline'] - df['launched_at']
df['actual_duration']   = df['state_changed_at'] - df['launched_at']

# %%
# feature engineering 2 (launch times)
df['launch_year']  = df['launched_at_dt'].dt.year
df['launch_month'] = df['launched_at_dt'].dt.month
df['launch_day']   = df['launched_at_dt'].dt.day
df['launch_hour']  = df['launched_at_dt'].dt.hour

# %%
# feature engineering 3 (deadline times)
df['deadline_year']  = df['deadline_dt'].dt.year
df['deadline_month'] = df['deadline_dt'].dt.month
df['deadline_day']   = df['deadline_dt'].dt.day

# %%
for col in unix_time_columns:
    df = df.drop(col, axis=1)
    df = df.drop(col+'_dt', axis=1)

# %%
print('Columns:\n{}'.format(df.columns.values))
print('Data Types:\n{}'.format(df.dtypes))
print('Shape:\n{}'.format(df.shape))
df.head()
# Out:
# Columns:
# ['name' 'desc' 'goal' 'keywords' 'disable_communication' 'country'
#  'backers_count' 'final_status' 'expected_duration' 'actual_duration'
#  'launch_year' 'launch_month' 'launch_day' 'launch_hour' 'deadline_year'
#  'deadline_month' 'deadline_day']
# Data Types:
# name                      object
# desc                      object
# goal                     float64
# keywords                  object
# disable_communication       bool
# country                   object
# backers_count              int64
# final_status               int64
# expected_duration          int64
# actual_duration            int64
# launch_year                int64
# launch_month               int64
# launch_day                 int64
# launch_hour                int64
# deadline_year              int64
# deadline_month             int64
# deadline_day               int64
# dtype: object
# Shape:
# (108129, 17)
#                                                              name  \
# project_id
# kkst1451568084                                drawing for dollars
# kkst1474482071  Sponsor Dereck Blackburn (Lostwars) Artist in ...
# kkst183622197                                       Mr. Squiggles
# kkst597742710                      Help me write my second novel.
# kkst1913131122             Support casting my sculpture in bronze
#
#                                                              desc    goal  \
# project_id
# kkst1451568084  I like drawing pictures. and then i color them...    20.0
# kkst1474482071  I, Dereck Blackburn will be taking upon an inc...   300.0
# kkst183622197   So I saw darkpony's successfully funded drawin...    30.0
# kkst597742710   Do your part to help out starving artists and ...   500.0
# kkst1913131122  I'm nearing completion on a sculpture, current...  2000.0
#
#                                                          keywords  \
# project_id
# kkst1451568084                                drawing-for-dollars
# kkst1474482071  sponsor-dereck-blackburn-lostwars-artist-in-re...
# kkst183622197                                        mr-squiggles
# kkst597742710                       help-me-write-my-second-novel
# kkst1913131122             support-casting-my-sculpture-in-bronze
#
#                 disable_communication country  backers_count  final_status  \
# project_id
# kkst1451568084                  False      US              3             1
# kkst1474482071                  False      US              2             0
# kkst183622197                   False      US              0             0
# kkst597742710                   False      US             18             1
# kkst1913131122                  False      US              1             0
#
#                 expected_duration  actual_duration  launch_year  launch_month  \
# project_id
# kkst1451568084             731276           731294         2009             4
# kkst1474482071            1453408          1456426         2009             4
# kkst183622197              863162           863420         2009             5
# kkst597742710             2589010          2589391         2009             4
# kkst1913131122            2589339          2589776         2009             5
#
#                 launch_day  launch_hour  deadline_year  deadline_month  \
# project_id
# kkst1451568084          24           19           2009               5
# kkst1474482071          29            3           2009               5
# kkst183622197           12           21           2009               5
# kkst597742710           29            0           2009               5
# kkst1913131122           1           12           2009               5
#
#                 deadline_day
# project_id
# kkst1451568084             3
# kkst1474482071            15
# kkst183622197             22
# kkst597742710             29
# kkst1913131122            31

# %%
dummy_cols = ['country',
              'launch_hour','launch_day','launch_month','launch_year',
              'deadline_day','deadline_month','deadline_year']
for col in dummy_cols:
    df = pd.merge(df, pd.get_dummies(df[col], prefix=col), left_index=True, right_index=True)
    df = df.drop(col, axis=1)
print('Columns:\n{}'.format(df.columns.values))
print('Data Types:\n{}'.format(df.dtypes))
print('Shape:\n{}'.format(df.shape))
# Out:
# Columns:
# ['name' 'desc' 'goal' 'keywords' 'disable_communication' 'backers_count'
#  'final_status' 'expected_duration' 'actual_duration' 'country_AU'
#  'country_CA' 'country_DE' 'country_DK' 'country_GB' 'country_IE'
#  'country_NL' 'country_NO' 'country_NZ' 'country_SE' 'country_US'
#  'launch_hour_0' 'launch_hour_1' 'launch_hour_2' 'launch_hour_3'
#  'launch_hour_4' 'launch_hour_5' 'launch_hour_6' 'launch_hour_7'
#  'launch_hour_8' 'launch_hour_9' 'launch_hour_10' 'launch_hour_11'
#  'launch_hour_12' 'launch_hour_13' 'launch_hour_14' 'launch_hour_15'
#  'launch_hour_16' 'launch_hour_17' 'launch_hour_18' 'launch_hour_19'
#  'launch_hour_20' 'launch_hour_21' 'launch_hour_22' 'launch_hour_23'
#  'launch_day_1' 'launch_day_2' 'launch_day_3' 'launch_day_4' 'launch_day_5'
#  'launch_day_6' 'launch_day_7' 'launch_day_8' 'launch_day_9'
#  'launch_day_10' 'launch_day_11' 'launch_day_12' 'launch_day_13'
#  'launch_day_14' 'launch_day_15' 'launch_day_16' 'launch_day_17'
#  'launch_day_18' 'launch_day_19' 'launch_day_20' 'launch_day_21'
#  'launch_day_22' 'launch_day_23' 'launch_day_24' 'launch_day_25'
#  'launch_day_26' 'launch_day_27' 'launch_day_28' 'launch_day_29'
#  'launch_day_30' 'launch_day_31' 'launch_month_1' 'launch_month_2'
#  'launch_month_3' 'launch_month_4' 'launch_month_5' 'launch_month_6'
#  'launch_month_7' 'launch_month_8' 'launch_month_9' 'launch_month_10'
#  'launch_month_11' 'launch_month_12' 'launch_year_2009' 'launch_year_2010'
#  'launch_year_2011' 'launch_year_2012' 'launch_year_2013'
#  'launch_year_2014' 'launch_year_2015' 'deadline_day_1' 'deadline_day_2'
#  'deadline_day_3' 'deadline_day_4' 'deadline_day_5' 'deadline_day_6'
#  'deadline_day_7' 'deadline_day_8' 'deadline_day_9' 'deadline_day_10'
#  'deadline_day_11' 'deadline_day_12' 'deadline_day_13' 'deadline_day_14'
#  'deadline_day_15' 'deadline_day_16' 'deadline_day_17' 'deadline_day_18'
#  'deadline_day_19' 'deadline_day_20' 'deadline_day_21' 'deadline_day_22'
#  'deadline_day_23' 'deadline_day_24' 'deadline_day_25' 'deadline_day_26'
#  'deadline_day_27' 'deadline_day_28' 'deadline_day_29' 'deadline_day_30'
#  'deadline_day_31' 'deadline_month_1' 'deadline_month_2' 'deadline_month_3'
#  'deadline_month_4' 'deadline_month_5' 'deadline_month_6'
#  'deadline_month_7' 'deadline_month_8' 'deadline_month_9'
#  'deadline_month_10' 'deadline_month_11' 'deadline_month_12'
#  'deadline_year_2009' 'deadline_year_2010' 'deadline_year_2011'
#  'deadline_year_2012' 'deadline_year_2013' 'deadline_year_2014'
#  'deadline_year_2015']
# Data Types:
# name                      object
# desc                      object
# goal                     float64
# keywords                  object
# disable_communication       bool
# backers_count              int64
# final_status               int64
# expected_duration          int64
# actual_duration            int64
# country_AU                 uint8
# country_CA                 uint8
# country_DE                 uint8
# country_DK                 uint8
# country_GB                 uint8
# country_IE                 uint8
# country_NL                 uint8
# country_NO                 uint8
# country_NZ                 uint8
# country_SE                 uint8
# country_US                 uint8
# launch_hour_0              uint8
# launch_hour_1              uint8
# launch_hour_2              uint8
# launch_hour_3              uint8
# launch_hour_4              uint8
# launch_hour_5              uint8
# launch_hour_6              uint8
# launch_hour_7              uint8
# launch_hour_8              uint8
# launch_hour_9              uint8
#                           ...
# deadline_day_21            uint8
# deadline_day_22            uint8
# deadline_day_23            uint8
# deadline_day_24            uint8
# deadline_day_25            uint8
# deadline_day_26            uint8
# deadline_day_27            uint8
# deadline_day_28            uint8
# deadline_day_29            uint8
# deadline_day_30            uint8
# deadline_day_31            uint8
# deadline_month_1           uint8
# deadline_month_2           uint8
# deadline_month_3           uint8
# deadline_month_4           uint8
# deadline_month_5           uint8
# deadline_month_6           uint8
# deadline_month_7           uint8
# deadline_month_8           uint8
# deadline_month_9           uint8
# deadline_month_10          uint8
# deadline_month_11          uint8
# deadline_month_12          uint8
# deadline_year_2009         uint8
# deadline_year_2010         uint8
# deadline_year_2011         uint8
# deadline_year_2012         uint8
# deadline_year_2013         uint8
# deadline_year_2014         uint8
# deadline_year_2015         uint8
# Length: 144, dtype: object
# Shape:
# (108129, 144)

# %%
# remove text fields for now
text_cols = ['name','desc','keywords']
df = df.drop(text_cols, axis=1)

# %%
# split into train and test
from sklearn.model_selection import train_test_split

X = df.drop('final_status',axis=1)
y = df['final_status']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.33, random_state=42)

# %%
from sklearn.naive_bayes import BernoulliNB
>>> gnb = BernoulliNB()
>>> y_pred = gnb.fit(X_train, y_train).predict(X_test)
>>> print("Number of mislabeled points out of a total %d points : %d"
...       % (X_test.shape[0],(y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 35683 points : 13249

# %%
from sklearn.naive_bayes import GaussianNB
>>> gnb = GaussianNB()
>>> y_pred = gnb.fit(X_train, y_train).predict(X_test)
>>> print("Number of mislabeled points out of a total %d points : %d"
...       % (X_test.shape[0],(y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 35683 points : 17843

# %%
# Out:
# 0.37129725639660344
